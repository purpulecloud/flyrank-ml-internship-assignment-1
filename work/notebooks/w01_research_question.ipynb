# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/purpulecloud/flyrank-ml-internship-assignemnt-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/purplecloud/flyrank-ml-internship-assignment-1.git
# Out:
# Cloning into 'flyrank-ml-internship-assignment-1'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose **Lane 2: Refresh / Content Opportunity Scoring**.
#
# The aim of this project is to build a ranking system that helps identify which webpages should be reviewed first for content improvements. Instead of checking every page manually, I want to use observable search and content signals to prioritize pages that are more likely to need attention. I chose this lane because it focuses on improving a real decision that content teams make rather than simply training a machine learning model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Which webpages should be reviewed first for content updates?
#
# **Who acts on it?** A content editor or SEO specialist.
#
# **Action:** Review the highest-ranked pages and decide whether they should be refreshed, expanded, monitored, or left unchanged.
#
# **Unit of analysis:** One webpage.
#
# **Output:** A ranked list of webpages with a priority score.
#
# **Cost of a wrong recommendation:** If the wrong pages are recommended, the team may spend time reviewing pages that do not need updates while important pages that require attention are delayed.
#
# **Why ML can help:** Page performance depends on several signals such as impressions, clicks, CTR, engagement, content age, and average position. Considering these signals together may help prioritize pages more effectively than relying on a single manual rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2–3 real numbers)
#
# The following statistics are taken directly from the starter dataset. They provide a quick overview of the data and show why ranking content review opportunities is worth investigating.

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 .
# drwxr-xr-x 1 root root 4096 Jul 15 10:28 ..
# drwxr-xr-x 4 root root 4096 Jun  4 13:32 .config
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data

# %%
# !find /content -maxdepth 2 -type d
# Out:
# /content
# /content/.config
# /content/.config/logs
# /content/.config/configurations
# /content/sample_data

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Unique clients:", df["client_id"].nunique())
print("Average CTR (%):", round(df["ctr"].mean(), 2))
print("Average impressions (90d):", round(df["impressions_90d"].mean(), 2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7535/1945631912.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
#       4
#       5 print("Total pages:", len(df))
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
